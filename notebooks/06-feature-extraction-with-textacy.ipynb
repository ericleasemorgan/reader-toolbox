# %% [markdown]
# # More feature extraction: Textacy

# %% [markdown]
# The Natural Language Toolkit is the grand daddy of text mining libraries/modules for Python, but since its inception, other tools have made themeselves available. One of those tools is called "Textacy". Textacy does many of the things done by the NLTK, and it does more. This extra functionality is both more complicated and more expressive than the 'Toolkit.

# %%
# configure
CARREL   = 'CodeOfConduct4Lib-2021-03-10'
TEMPLATE = './carrels/%s/etc/reader.txt'
KEYWORD = 'code'
MODEL   = 'en_core_web_sm'

# %%
# require
import textacy
import os
import spacy
from textacy.ke import yake

# %%
# slurp up some plain text...
file   = TEMPLATE % CARREL
data = open( file ).read()

# ...and do the tiniest bit of normalization ("cleaning") against it
data = data.replace( '\n', ' ' ).replace( '\t', ' ').replace( '  ', ' ')

# %%
# perform a keyword in context (KWIC) query against the data; concordance
result = textacy.text_utils.KWIC( data, KEYWORD )
print( list( result ) )
# Out:
#                                                    code ofconduct lib cc licensed under cc short link: htt
# censed under cc short link: http://bit.ly/coc lib  code  lib seeks to provide a welcoming, professionally
# ent by having that initial discussion themselves.  code  lib understands that there are many reasons speak
# ommunity support squad volunteers list, or on the  code  lib wiki.. if you can't find either any such peop
#  you want to ensure anonymity. if you are in the # code  lib irc channel, the zoia command to list people
# know how to direct you to them. if you are in the  code  lib slack, you may reach a volunteer by including
#  posted to a public channel, such as #general or # code  libcon. you may also private message a known memb
# publicly-accessible website(s). if you are in the  code  lib discord server, contact anyone who is assigne
# ing the offender, expelling the offender from the  code  lib event, or banning the offender from a chatroo
# e offender not be allowed to volunteer for future  code  lib events (either indefinitely or for a specifie
# od) banning the offender from any (or all) online  code  lib channels publishing an account of the harassm
#  channels publishing an account of the harassment  code  lib event organizers can be identified by their n
#  support volunteers: including the [phone number]  code  lib irc volunteers: @helpers in #code lib, or /ms
# one number] code lib irc volunteers: @helpers in # code  lib, or /msg zoia helpers #code lib we expect par
# ers: @helpers in #code lib, or /msg zoia helpers # code  lib we expect participants to follow these rules
# hannels. we value everyone's participation in the  code  lib community, and will all work to keep code lib
# the code lib community, and will all work to keep  code  lib a safe and friendly space for all participant
# []

# %%
# create a spaCy "doc object"; depending on the size of the input, this may take a few minutes to process
size           = os.stat( file ).st_size
nlp            = spacy.load( MODEL  )
nlp.max_length = size
doc            = nlp( data )

# %%
doc._.preview
# Out:
# 'Doc(1442 tokens: " codeofconduct lib cc licensed under cc short l...")'

# %%
textacy.TextStats( doc ).flesch_reading_ease
# Out:
# 41.32295496887835

# %%
list(textacy.extract.ngrams( doc, 2, filter_stops=True, filter_punct=True, filter_nums=False) )
# Out:
# [codeofconduct lib,
#  lib cc,
#  cc licensed,
#  cc short,
#  short link,
#  http://bit.ly/coc lib,
#  lib code,
#  code lib,
#  lib seeks,
#  professionally engaging,
#  safe conference,
#  ongoing community,
#  tolerate harassment,
#  discriminatory language,
#  including sexual,
#  sexualized language,
#  event venue,
#  including talks,
#  community channel,
#  mailing list,
#  unsafe environment,
#  includes offensive,
#  offensive verbal,
#  verbal comments,
#  verbal expressions,
#  expressions related,
#  gender identity,
#  gender expression,
#  sexual orientation,
#  physical appearance,
#  body size,
#  political beliefs,
#  discriminatory images,
#  including online,
#  deliberate intimidation,
#  harassing photography,
#  sustained disruption,
#  inappropriate physical,
#  physical contact,
#  unwelcome sexual,
#  sexual attention,
#  conflict resolution,
#  resolution initial,
#  initial incident,
#  feel comfortable,
#  comfortable speaking,
#  offending behavior,
#  initial discussion,
#  code lib,
#  lib understands,
#  reasons speaking,
#  speaking directly,
#  personal safety,
#  feel comfortable,
#  comfortable speaking,
#  speaking directly,
#  skip straight,
#  offender insists,
#  actively harassing,
#  direct engagement,
#  good option,
#  community event,
#  community support,
#  support volunteer,
#  event organizer,
#  staff person,
#  accessible website,
#  conference website,
#  community support,
#  support squad,
#  squad volunteers,
#  volunteers list,
#  code lib,
#  lib wiki,
#  staff available,
#  situation calls,
#  immediate action,
#  primary way,
#  community support,
#  support volunteer,
#  volunteer online,
#  c lcommunitysupport@googlegroups.com,
#  lcommunitysupport@googlegroups.com address,
#  messages sent,
#  csv list,
#  community support,
#  support volunteers,
#  kept private,
#  away email,
#  email address,
#  ensure anonymity,
#  code lib,
#  lib irc,
#  irc channel,
#  zoia command,
#  list people,
#  people designated,
#  channel helpers,
#  community support,
#  support volunteers,
#  code lib,
#  lib slack,
#  phrase c,
#  c lcsv,
#  c lcss,
#  message posted,
#  public channel,
#  code libcon,
#  private message,
#  known member,
#  community support,
#  support squad,
#  slack handles,
#  aforementioned publicly,
#  accessible website(s,
#  code lib,
#  lib discord,
#  discord server,
#  @community_support_volunteers role,
#  green highlighted,
#  highlighted user,
#  community support,
#  support volunteer,
#  desktop discord,
#  discord client,
#  upper right,
#  right corner,
#  public messages,
#  eric lease,
#  lease morgan,
#  community support,
#  support volunteers,
#  wider community,
#  community response,
#  discussion reveals,
#  reveals offense,
#  apologies offered,
#  public note,
#  outside intervention,
#  incident results,
#  corrective action,
#  choose corrective,
#  corrective action,
#  like ending,
#  talk early,
#  step runs,
#  issues implementing,
#  real life,
#  particular decision,
#  asking people,
#  stop people,
#  people sharing,
#  steer discussions,
#  constructive dialogue,
#  sanctions participants,
#  participants asked,
#  harassing behavior,
#  comply immediately,
#  participant engages,
#  harassing behavior,
#  deem appropriate,
#  including warning,
#  code lib,
#  lib event,
#  slack workspace,
#  mailing list,
#  specific sanctions,
#  sanctions requiring,
#  physical proximity,
#  event terminating,
#  talk refusing,
#  publish video,
#  video and/or,
#  and/or slides,
#  talk barring,
#  event immediately,
#  immediately ending,
#  event volunteer,
#  volunteer responsibilities,
#  offender holds,
#  including requiring,
#  future code,
#  code lib,
#  lib events,
#  specified time,
#  time period,
#  offender immediately,
#  immediately leave,
#  return banning,
#  future events,
#  specified time,
#  time period,
#  online code,
#  code lib,
#  lib channels,
#  channels publishing,
#  harassment code,
#  code lib,
#  lib event,
#  event organizers,
#  help participants,
#  participants contact,
#  contact hotel,
#  venue security,
#  local law,
#  law enforcement,
#  provide escorts,
#  experiencing harassment,
#  feel safe,
#  organized events,
#  readily available,
#  following information,
#  conference organizer,
#  phone number,
#  conference hotel,
#  phone number,
#  police department,
#  phone number,
#  local sexual,
#  sexual assault,
#  crisis line,
#  phone number,
#  taxi company,
#  phone number,
#  community support,
#  support volunteers,
#  phone number,
#  code lib,
#  lib irc,
#  irc volunteers,
#  code lib,
#  /msg zoia,
#  zoia helpers,
#  code lib,
#  expect participants,
#  conference venues,
#  related social,
#  social events,
#  community gatherings,
#  online communication,
#  communication channels,
#  code lib,
#  lib community,
#  code lib,
#  friendly space,
#  example policy,
#  geek feminism,
#  feminism wiki,
#  ada initiative]

# %%
yake( doc )
# Out:
# [('community', 0.16129525407839013),
#  ('lib', 0.17105750584987534),
#  ('code', 0.17175691455112038),
#  ('offender', 0.17277388872364463),
#  ('event', 0.1846411322382838),
#  ('volunteer', 0.1949806304418236),
#  ('support', 0.20092741544357734),
#  ('list', 0.24882729969551),
#  ('conference', 0.24984179958301242),
#  ('code lib', 0.2507713303348389)]

# %%
list( textacy.extract.entities( doc ) )
# Out:
# [third, at least one, #, eric, first]

# %%
list( textacy.extract.subject_verb_object_triples( doc ) )
# Out:
# [(code lib, seeks, to provide),
#  (we, do not tolerate, harassment),
#  (that, produces, environment),
#  (it, includes, comments),
#  (it, includes, expressions),
#  (it, includes, disruption),
#  (they, have affected, you),
#  (offender, may resolve, incident),
#  (offended, may resolve, incident),
#  (offender, harassing, you),
#  (engagement, is not, option),
#  (escalation, will need, party),
#  (escalation, will need, to step),
#  (you, will need, party),
#  (you, will need, to step),
#  (you, can't find, people),
#  (there, will be, staff),
#  (you, may use, email address),
#  (you, want, to ensure),
#  (helpers, may not be, support volunteers),
#  (you, may reach, volunteer),
#  (who, is assigned, @community_support_volunteers role),
#  (who, are designated, role),
#  (those, will have, user name),
#  (someone, is, support volunteer),
#  (you, can see, list),
#  (listserv, does have, maintainer),
#  (listserv, does have, lease morgan),
#  (incident, doesn't pass, step),
#  (discussion, reveals, offense),
#  (discussion, reveals, apologies),
#  (community, should support, decision),
#  (they, choose, action),
#  (community, should revise, coc),
#  (people, will have, opinions),
#  (people, sharing, opinions),
#  (we, can steer, discussions),
#  (sanctions participants, asked, to stop),
#  (organizers, may take, action),
#  (they, deem, appropriate),
#  (offender, not be allowed, to volunteer),
#  (offender, leave, event),
#  (they, will help, participants),
#  (those, should make, information),
#  (participants, to follow, rules),
#  (we, value, participation)]

# %%
list( textacy.extract.noun_chunks( doc ) )
# Out:
# [ codeofconduct lib cc,
#  cc short link,
#  http://bit.ly/coc lib code lib,
#  welcoming,
#  fun,
#  safe conference,
#  ongoing community,
#  ) experience,
#  everyone,
#  we,
#  harassment,
#  form,
#  discriminatory language,
#  imagery,
#  sexual or sexualized language,
#  imagery,
#  event venue,
#  talks,
#  community channel,
#  chatroom,
#  mailing list,
#  harassment,
#  behavior,
#  person,
#  group,
#  unsafe environment,
#  it,
#  offensive verbal comments,
#  non-verbal expressions,
#  gender,
#  gender identity,
#  gender expression,
#  sexual orientation,
#  disability,
#  physical appearance,
#  body size,
#  race,
#  age,
#  religious or political beliefs,
#  sexual, sexualized, or discriminatory images,
#  public,
#  online) spaces,
#  deliberate intimidation,
#  photography,
#  recording,
#  sustained disruption,
#  talks,
#  other events,
#  inappropriate physical contact,
#  sexual attention,
#  conflict resolution initial incident,
#  you,
#  someone,
#  other concerns,
#  you,
#  offender,
#  offender,
#  they,
#  you,
#  offending behavior,
#  offender,
#  incident,
#  initial discussion,
#  themselves,
#  code lib,
#  many reasons,
#  offender,
#  you,
#  unfamiliarity,
#  conference,
#  its participants,
#  spoons,
#  personal safety,
#  you,
#  offender,
#  reason,
#  escalation,
#  offender,
#  they,
#  offender,
#  you,
#  direct engagement,
#  good option,
#  you,
#  time,
#  you,
#  third party,
#  you,
#  conference,
#  other community event,
#  on-call community support volunteer,
#  event organizer or staff person,
#  who,
#  publicly-accessible website,
#  conference website,
#  community support squad volunteers list,
#  code lib wiki,
#  you,
#  either any such people,
#  other staff,
#  situation,
#  immediate action,
#  primary way,
#  community support volunteer,
#  c lcommunitysupport@googlegroups.com address,
#  messages,
#  csv list,
#  community support volunteers,
#  you,
#  throw-away email address,
#  you,
#  anonymity,
#  you,
#  #code lib,
#  irc channel,
#  zoia command,
#  people,
#  channel helpers,
#  @helpers,
#  at least one helper,
#  channel,
#  most times,
#  helpers,
#  community support volunteers,
#  you,
#  them,
#  you,
#  code lib slack,
#  you,
#  volunteer,
#  either the phrase,
#  lcsv,
#  lcss,
#  message,
#  public channel,
#  you,
#  known member,
#  community support squad,
#  their names,
#  slack handles,
#  aforementioned publicly-accessible website(s,
#  you,
#  code lib discord server,
#  anyone,
#  who,
#  @community_support_volunteers role,
#  who,
#  role,
#  green highlighted user name,
#  who,
#  color,
#  you,
#  someone,
#  community support volunteer,
#  their name/profile,
#  @community_support_volunteers,
#  roles,
#  desktop discord client,
#  you,
#  list,
#  role,
#  upper right corner,
#  you,
#  listserv,
#  you,
#  all,
#  public messages,
#  listserv,
#  maintainer,
#  eric lease morgan,
#  addition,
#  community support volunteers,
#  whom,
#  you,
#  wider community response,
#  incident,
#  incident,
#  first step,
#  discussion,
#  offense,
#  apologies,
#  public note,
#  community,
#  resolution,
#  community,
#  point,
#  incident,
#  outside intervention,
#  incident,
#  corrective action,
#  community,
#  decision,
#  help,
#  step,
#  they,
#  corrective action,
#  talk,
#  listserv,
#  support,
#  incident,
#  individuals,
#  help,
#  step,
#  issues,
#  coc,
#  help,
#  community,
#  issues,
#  community,
#  coc,
#  they,
#  real life,
#  people,
#  opinions,
#  coc,
#  people,
#  particular decision,
#  others,
#  it,
#  we,
#  people,
#  people,
#  their opinions,
#  we,
#  discussions,
#  civil, constructive dialogue,
#  something,
#  (e.g., affirmation,
#  decision,
#  coc,
#  modification,
#  decision,
#  sanctions participants,
#  harassing behavior,
#  participant,
#  behavior,
#  organizers,
#  action,
#  they,
#  offender,
#  offender,
#  code lib event,
#  offender,
#  chatroom,
#  slack workspace,
#  mailing list,
#  specific sanctions,
#  offender,
#  their behavior,
#  them,
#  further reports,
#  other sanctions,
#  offender,
#  interaction,
#  physical proximity,
#  victim,
#  remainder,
#  event,
#  talk,
#  video,
#  slides,
#  talk,
#  speaker,
#  ) talks,
#  event,
#  event volunteer responsibilities,
#  privileges,
#  offender,
#  offender,
#  future code lib events,
#  specified time period,
#  offender,
#  event,
#  offender,
#  future events,
#  specified time period,
#  offender,
#  (or all) online code lib channels,
#  account,
#  harassment code lib event,
#  organizers,
#  their name badges,
#  they,
#  participants,
#  hotel/venue security,
#  local law enforcement,
#  escorts,
#  harassment,
#  duration,
#  event,
#  case,
#  organized events,
#  event,
#  following information,
#  conference organizer,
#  organizer name,
#  phone number,
#  conference hotel name,
#  phone number,
#  [municipality] police department,
#  phone number,
#  local sexual assault/crisis line,
#  phone number,
#  [taxi company name]: [phone number] community support volunteers,
#  [phone number,
#  code lib,
#  volunteers,
#  @helpers,
#  #code lib,
#  zoia helpers,
#  #code lib,
#  we,
#  participants,
#  rules,
#  conference venues,
#  conference-related social events,
#  community gatherings,
#  online communication channels,
#  we,
#  everyone's participation,
#  code lib community,
#  code lib,
#  safe and friendly space,
#  participants,
#  example policy,
#  geek feminism wiki,
#  ada initiative,
#  other volunteers]

# %%
list( textacy.extract.semistructured_statements( doc, entity='you', cue='be' ) )
# Out:
# [(you, are, at a conference or other community event),
#  (you, are, in the #code lib irc channel),
#  (you, are, in the code lib slack),
#  (you, are, in the code lib discord server),
#  (you, are, on the listserv),
#  (you, 're, in a free-for-all for public messages),
#  (you, are, welcome to involve)]
